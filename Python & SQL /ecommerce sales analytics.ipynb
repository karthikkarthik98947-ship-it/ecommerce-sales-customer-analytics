# %%
import pandas  as pd
import numpy as np
df = pd.read_csv(r"c:/Users/karth/OneDrive/Desktop/python/ecommerce_sales_analytics_1000.csv")
print(df)
# Out:
#      Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0       10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1       10002  2025-05-11       C1150      Backpack         Fashion         1
# 2       10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3       10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4       10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
# ..        ...         ...         ...           ...             ...       ...
# 995     10996  2025-07-25       C1024    Headphones     Electronics         2
# 996     10997  2025-11-01       C1098  Coffee Maker  Home & Kitchen         2
# 997     10998  2025-01-07       C1127       T-Shirt         Fashion         4
# 998     10999  2025-05-12       C1108       T-Shirt         Fashion         3
# 999     11000  2025-09-07       C1148       T-Shirt         Fashion         3
#
# ...

# %%
df.head(10)
# Out:
#    Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0     10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1     10002  2025-05-11       C1150      Backpack         Fashion         1
# 2     10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3     10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4     10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
# 5     10006  2025-08-30       C1009         Shoes         Fashion         4
# 6     10007  2025-09-21       C1175    Smartphone     Electronics         2
# 7     10008  2025-02-23       C1106     Desk Lamp  Home & Kitchen         2
# 8     10009  2025-09-27       C1095         Novel           Books         1
# 9     10010  2025-08-01       C1082         Jeans         Fashion         3
#
#    Price  Sales      City        State Payment_Method  Rating
# 0   1450   2900   Kolkata  West Bengal    Credit Card       5
# ...

# %%
df.tail(5)
# Out:
#      Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 995     10996  2025-07-25       C1024    Headphones     Electronics         2
# 996     10997  2025-11-01       C1098  Coffee Maker  Home & Kitchen         2
# 997     10998  2025-01-07       C1127       T-Shirt         Fashion         4
# 998     10999  2025-05-12       C1108       T-Shirt         Fashion         3
# 999     11000  2025-09-07       C1148       T-Shirt         Fashion         3
#
#      Price  Sales        City        State Payment_Method  Rating
# 995   7650  15300       Kochi       Kerala     Debit Card       4
# 996   4300   8600     Kolkata  West Bengal            UPI       5
# 997    800   3200        Pune  Maharashtra    Credit Card       5
# 998    800   2400  Coimbatore   Tamil Nadu            UPI       2
# 999   1400   4200       Hubli    Karnataka            UPI       4

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Product', 'Category',
#        'Quantity', 'Price', 'Sales', 'City', 'State', 'Payment_Method',
#        'Rating'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        1000 non-null   int64
#  1   Order_Date      1000 non-null   str
#  2   Customer_ID     1000 non-null   str
#  3   Product         1000 non-null   str
#  4   Category        1000 non-null   str
#  5   Quantity        1000 non-null   int64
#  6   Price           1000 non-null   int64
#  7   Sales           1000 non-null   int64
#  8   City            1000 non-null   str
#  9   State           1000 non-null   str
#  10  Payment_Method  1000 non-null   str
#  11  Rating          1000 non-null   int64
# dtypes: int64(5), str(7)
# memory usage: 93.9 KB

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.describe()
# Out:
#            Order_ID    Quantity         Price          Sales      Rating
# count   1000.000000  1000.00000   1000.000000    1000.000000  1000.00000
# mean   10500.500000     2.36600   7987.100000   19277.200000     3.83900
# std      288.819436     1.40571  14944.698646   42798.548292     1.13153
# min    10001.000000     1.00000    100.000000     100.000000     1.00000
# 25%    10250.750000     1.00000   1250.000000    2037.500000     3.00000
# 50%    10500.500000     2.00000   2525.000000    5200.000000     4.00000
# 75%    10750.250000     3.00000   5950.000000   13800.000000     5.00000
# max    11000.000000     5.00000  74750.000000  360750.000000     5.00000

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Product           0
# Category          0
# Quantity          0
# Price             0
# Sales             0
# City              0
# State             0
# Payment_Method    0
# Rating            0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Order_ID          False
# Order_Date        False
# Customer_ID       False
# Product           False
# Category          False
# Quantity          False
# Price             False
# Sales             False
# City              False
# State             False
# Payment_Method    False
# Rating            False
# dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df.duplicated)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product, Category, Quantity, Price, Sales, City, State, Payment_Method, Rating]
# Index: []

# %%
df.drop_duplicates()
# Out:
#      Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0       10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1       10002  2025-05-11       C1150      Backpack         Fashion         1
# 2       10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3       10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4       10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
# ..        ...         ...         ...           ...             ...       ...
# 995     10996  2025-07-25       C1024    Headphones     Electronics         2
# 996     10997  2025-11-01       C1098  Coffee Maker  Home & Kitchen         2
# 997     10998  2025-01-07       C1127       T-Shirt         Fashion         4
# 998     10999  2025-05-12       C1108       T-Shirt         Fashion         3
# 999     11000  2025-09-07       C1148       T-Shirt         Fashion         3
#
# ...

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df["Order_Date"].dt.year
# Out:
# 0      2025
# 1      2025
# 2      2025
# 3      2025
# 4      2025
#        ...
# 995    2025
# 996    2025
# 997    2025
# 998    2025
# 999    2025
# Name: Order_Date, Length: 1000, dtype: int32

# %%
df["Year"]=df["Order_Date"].dt.year

# %%
df["Order_Date"].dt.year
df.head()
# Out:
#    Order_ID Order_Date Customer_ID       Product        Category  Quantity  \
# 0     10001 2025-01-21       C1103       T-Shirt         Fashion         2
# 1     10002 2025-05-11       C1150      Backpack         Fashion         1
# 2     10003 2025-11-10       C1022    Smartwatch     Electronics         3
# 3     10004 2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4     10005 2025-05-11       C1051  Cookware Set  Home & Kitchen         3
#
#    Price  Sales      City        State Payment_Method  Rating  Year
# 0   1450   2900   Kolkata  West Bengal    Credit Card       5  2025
# 1   3150   3150   Chennai   Tamil Nadu            UPI       3  2025
# 2   5150  15450     Kochi       Kerala            UPI       3  2025
# 3   1700   1700     Delhi        Delhi    Credit Card       1  2025
# 4   2600   7800  Warangal    Telangana     Debit Card       5  2025

# %%
df["Order_Date"].dt.month_name()
# Out:
# 0        January
# 1            May
# 2       November
# 3           July
# 4            May
#          ...
# 995         July
# 996     November
# 997      January
# 998          May
# 999    September
# Name: Order_Date, Length: 1000, dtype: str

# %%
df["Order_Date"].dt.day
# Out:
# 0      21
# 1      11
# 2      10
# 3       7
# 4      11
#        ..
# 995    25
# 996     1
# 997     7
# 998    12
# 999     7
# Name: Order_Date, Length: 1000, dtype: int32

# %%
df[["Quantity","Sales","Price"]].head(10)
# Out:
#    Quantity  Sales  Price
# 0         2   2900   1450
# 1         1   3150   3150
# 2         3  15450   5150
# 3         1   1700   1700
# 4         3   7800   2600
# 5         4   5000   1250
# 6         2  49500  24750
# 7         2   1700    850
# 8         1    550    550
# 9         3   3900   1300

# %%
df["calc_sales"] = df["Quantity"] * df["Price"]

# %%
df[["Quantity","Sales","Price","calc_sales"]].head(10)
# Out:
#    Quantity  Sales  Price  calc_sales
# 0         2   2900   1450        2900
# 1         1   3150   3150        3150
# 2         3  15450   5150       15450
# 3         1   1700   1700        1700
# 4         3   7800   2600        7800
# 5         4   5000   1250        5000
# 6         2  49500  24750       49500
# 7         2   1700    850        1700
# 8         1    550    550         550
# 9         3   3900   1300        3900

# %%
print(df["Sales"] == df["calc_sales"].all())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 print(df["Sales"] == df["calc_sales"].all().value_count())
#
# AttributeError: 'numpy.bool' object has no attribute 'value_count'

# %%
print(len(df["Sales"] == df["calc_sales"].all()))
# Out:
# 1000

# %%
print(len(df["Sales"] != df["calc_sales"].all()))
# Out:
# 1000

# %%
df["Order_ID"].nunique()
# Out:
# 1000

# %%
df["Quantity"].sum()
# Out:
# np.int64(2366)

# %%
df["Sales"].sum()
# Out:
# np.int64(19277200)

# %%
tot_sales = df["Sales"].sum()
no_of_orders = df["Order_ID"].nunique()
aov = tot_sales / no_of_orders 
print("total_order_value:",aov)
# Out:
# total_order_value: 19277.2

# %%
df["Quantity"].mean()
# Out:
# np.float64(2.366)

# %%
df["Rating"].mean()
# Out:
# np.float64(3.839)

# %%
df["Cost_Price"] = df["Price"] * 0.70

# %%
df["Profit"] = df["Sales"] - df["Cost_Price"]

# %%
df["Profit"].sum()
# Out:
# np.float64(13686230.0)

# %%
df.loc[df["Sales"].idxmax()]
# Out:
# Order_ID                10059
# Order_Date         2025-01-12
# Customer_ID             C1095
# Product                Laptop
# Category          Electronics
# Quantity                    5
# Price                   72150
# Sales                  360750
# City                    Kochi
# State                  Kerala
# Payment_Method            UPI
# Rating                      3
# Cost_Price            50505.0
# Profit               310245.0
# Name: 58, dtype: object

# %%
df.loc[df["Sales"].idxmin()]
# Out:
# Order_ID                10393
# Order_Date         2025-05-19
# Customer_ID             C1103
# Product              Notebook
# Category                Books
# Quantity                    1
# Price                     100
# Sales                     100
# City                    Kochi
# State                  Kerala
# Payment_Method    Credit Card
# Rating                      3
# Cost_Price               70.0
# Profit                   30.0
# Name: 392, dtype: object

# %%
df["Product"].nunique()
# Out:
# 20

# %%
df["Product"].value_counts()
# Out:
# Product
# Desk Lamp           63
# Smartwatch          61
# Novel               59
# Keyboard            53
# Notebook            53
# Mouse               52
# Programming Book    52
# Bedsheet            52
# Coffee Maker        49
# T-Shirt             48
# Jacket              48
# Shoes               47
# Smartphone          47
# Headphones          47
# Mixer Grinder       47
# Backpack            46
# Monitor             46
# Cookware Set        45
# Laptop              45
# Jeans               40
# Name: count, dtype: int64

# %%
df.groupby("Product")["Quantity"].sum()
# Out:
# Product
# Backpack            107
# Bedsheet            120
# Coffee Maker        103
# Cookware Set        127
# Desk Lamp           156
# Headphones          124
# Jacket              115
# Jeans                74
# Keyboard            118
# Laptop              106
# Mixer Grinder       126
# Monitor             122
# Mouse               121
# Notebook            134
# Novel               131
# Programming Book    126
# Shoes               106
# Smartphone          109
# Smartwatch          141
# T-Shirt             100
# Name: Quantity, dtype: int64

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Backpack             211600
# Bedsheet             198400
# Coffee Maker         445550
# Cookware Set         546950
# Desk Lamp            244500
# Headphones           538700
# Jacket               534200
# Jeans                155900
# Keyboard             350500
# Laptop              6522850
# Mixer Grinder        696150
# Monitor             2387650
# Mouse                171650
# Notebook              38800
# Novel                 82900
# Programming Book     138950
# Shoes                390950
# Smartphone          4375750
# Smartwatch          1146000
# T-Shirt               99250
# Name: Sales, dtype: int64

# %%
df.groupby("Product")["Sales"].sum().sort_values(ascending = False)
# Out:
# Product
# Laptop              6522850
# Smartphone          4375750
# Monitor             2387650
# Smartwatch          1146000
# Mixer Grinder        696150
# Cookware Set         546950
# Headphones           538700
# Jacket               534200
# Coffee Maker         445550
# Shoes                390950
# Keyboard             350500
# Desk Lamp            244500
# Backpack             211600
# Bedsheet             198400
# Mouse                171650
# Jeans                155900
# Programming Book     138950
# T-Shirt               99250
# Novel                 82900
# Notebook              38800
# Name: Sales, dtype: int64

# %%
df.groupby("Product")["Quantity"].sum().nlargest()
# Out:
# Product
# Desk Lamp       156
# Smartwatch      141
# Notebook        134
# Novel           131
# Cookware Set    127
# Name: Quantity, dtype: int64

# %%
df.groupby("Product")["Sales"].sum().sort_values(ascending = False)
# Out:
# Product
# Laptop              6522850
# Smartphone          4375750
# Monitor             2387650
# Smartwatch          1146000
# Mixer Grinder        696150
# Cookware Set         546950
# Headphones           538700
# Jacket               534200
# Coffee Maker         445550
# Shoes                390950
# Keyboard             350500
# Desk Lamp            244500
# Backpack             211600
# Bedsheet             198400
# Mouse                171650
# Jeans                155900
# Programming Book     138950
# T-Shirt               99250
# Novel                 82900
# Notebook              38800
# Name: Sales, dtype: int64

# %%
df.groupby("Category")["Sales"].sum().sort_values(ascending = False)
# Out:
# Category
# Electronics       15493100
# Home & Kitchen     2131550
# Fashion            1391900
# Books               260650
# Name: Sales, dtype: int64

# %%
df.groupby("Category")["Quantity"].sum().sort_values(ascending = False)
# Out:
# Category
# Electronics       841
# Home & Kitchen    632
# Fashion           502
# Books             391
# Name: Quantity, dtype: int64

# %%
df.groupby("Product")["Sales"].agg(["sum","mean","count","idxmax"])
# Out:
#                       sum           mean  count  idxmax
# Product
# Backpack           211600    4600.000000     46     666
# Bedsheet           198400    3815.384615     52      56
# Coffee Maker       445550    9092.857143     49     516
# Cookware Set       546950   12154.444444     45     155
# Desk Lamp          244500    3880.952381     63     625
# Headphones         538700   11461.702128     47     401
# Jacket             534200   11129.166667     48     934
# Jeans              155900    3897.500000     40     441
# Keyboard           350500    6613.207547     53     832
# Laptop            6522850  144952.222222     45      58
# Mixer Grinder      696150   14811.702128     47     321
# Monitor           2387650   51905.434783     46     803
# Mouse              171650    3300.961538     52     874
# Notebook            38800     732.075472     53     120
# Novel               82900    1405.084746     59     482
# Programming Book   138950    2672.115385     52     778
# ...

# %%
df["Customer_ID"].nunique()
# Out:
# 200

# %%
df.groupby("Customer_ID")["Order_ID"].count().nlargest()
# Out:
# Customer_ID
# C1098    12
# C1063    11
# C1127    11
# C1004    10
# C1078    10
# Name: Order_ID, dtype: int64

# %%
df.groupby("Customer_ID")["Sales"].sum().sort_values(ascending = False)
# Out:
# Customer_ID
# C1065    445200
# C1095    431200
# C1063    366400
# C1104    364450
# C1110    354650
#           ...
# C1080      2000
# C1011      1950
# C1001      1300
# C1182      1250
# C1028       800
# Name: Sales, Length: 200, dtype: int64

# %%
df.groupby("Customer_ID")["Sales"].mean()
# Out:
# Customer_ID
# C1001     1300.000000
# C1002    74533.333333
# C1003    27000.000000
# C1004    17285.000000
# C1005    20510.000000
#              ...
# C1196    42612.500000
# C1197     3450.000000
# C1198     4580.000000
# C1199     6850.000000
# C1200    61800.000000
# Name: Sales, Length: 200, dtype: float64

# %%
df.groupby("Customer_ID").agg(
    Total_Sales=("Sales", "sum"),
    Total_Orders=("Order_ID", "count"),
    Total_Quantity=("Quantity", "sum"),
    Average_Sales=("Sales", "mean")
)
# Out:
#              Total_Sales  Total_Orders  Total_Quantity  Average_Sales
# Customer_ID
# C1001               1300             1               1    1300.000000
# C1002             223600             3               9   74533.333333
# C1003             135000             5               8   27000.000000
# C1004             172850            10              20   17285.000000
# C1005             102550             5              14   20510.000000
# ...                  ...           ...             ...            ...
# C1196             340900             8              27   42612.500000
# C1197               3450             1               3    3450.000000
# C1198              22900             5              10    4580.000000
# C1199              27400             4               6    6850.000000
# C1200             247200             4              10   61800.000000
#
# [200 rows x 4 columns]

# %%
df.groupby("Customer_ID")["Sales"].sum().sort_values(ascending = False)
# Out:
# Customer_ID
# C1065    445200
# C1095    431200
# C1063    366400
# C1104    364450
# C1110    354650
#           ...
# C1080      2000
# C1011      1950
# C1001      1300
# C1182      1250
# C1028       800
# Name: Sales, Length: 200, dtype: int64

# %%
df["Customer_ID"].value_counts()
# Out:
# Customer_ID
# C1098    12
# C1063    11
# C1127    11
# C1099    10
# C1004    10
#          ..
# C1171     1
# C1001     1
# C1037     1
# C1091     1
# C1121     1
# Name: count, Length: 200, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Kochi         100
# Ahmedabad      83
# Mumbai         82
# Hyderabad      81
# Pune           79
# Bangalore      79
# Warangal       78
# Hubli          78
# Chennai        76
# Mysore         74
# Kolkata        64
# Delhi          63
# Coimbatore     63
# Name: count, dtype: int64

# %%
df.groupby("City")["Sales"].sum().sort_values(ascending = False)
# Out:
# City
# Mysore        2330900
# Mumbai        2035800
# Warangal      2031150
# Kochi         1990650
# Bangalore     1672800
# Hubli         1637900
# Kolkata       1628500
# Hyderabad     1418150
# Pune          1196750
# Ahmedabad     1142000
# Chennai        824200
# Coimbatore     767550
# Delhi          600850
# Name: Sales, dtype: int64

# %%
df["Cost"] = df["Sales"] * 0.70
df["Profit"] = df["Sales"] - df["Cost"]

# %%
df.groupby("City")["Profit"].sum().sort_values(ascending = False)
# Out:
# City
# Mysore        699270.0
# Mumbai        610740.0
# Warangal      609345.0
# Kochi         597195.0
# Bangalore     501840.0
# Hubli         491370.0
# Kolkata       488550.0
# Hyderabad     425445.0
# Pune          359025.0
# Ahmedabad     342600.0
# Chennai       247260.0
# Coimbatore    230265.0
# Delhi         180255.0
# Name: Profit, dtype: float64

# %%
df.groupby("City")["Sales"].mean()
# Out:
# City
# Ahmedabad     13759.036145
# Bangalore     21174.683544
# Chennai       10844.736842
# Coimbatore    12183.333333
# Delhi          9537.301587
# Hubli         20998.717949
# Hyderabad     17508.024691
# Kochi         19906.500000
# Kolkata       25445.312500
# Mumbai        24826.829268
# Mysore        31498.648649
# Pune          15148.734177
# Warangal      26040.384615
# Name: Sales, dtype: float64

# %%
df["State"].value_counts()
# Out:
# State
# Karnataka      231
# Maharashtra    161
# Telangana      159
# Tamil Nadu     139
# Kerala         100
# Gujarat         83
# West Bengal     64
# Delhi           63
# Name: count, dtype: int64

# %%
df.groupby("State")["Sales"].sum().nlargest(10)
# Out:
# State
# Karnataka      5641600
# Telangana      3449300
# Maharashtra    3232550
# Kerala         1990650
# West Bengal    1628500
# Tamil Nadu     1591750
# Gujarat        1142000
# Delhi           600850
# Name: Sales, dtype: int64

# %%
df.groupby("State")["Profit"].sum().nlargest(8)
# Out:
# State
# Karnataka      1692480.0
# Telangana      1034790.0
# Maharashtra     969765.0
# Kerala          597195.0
# West Bengal     488550.0
# Tamil Nadu      477525.0
# Gujarat         342600.0
# Delhi           180255.0
# Name: Profit, dtype: float64

# %%
df.groupby("City")["Category"].value_counts()
# Out:
# City        Category
# Ahmedabad   Electronics       28
#             Home & Kitchen    25
#             Books             16
#             Fashion           14
# Bangalore   Electronics       27
#             Fashion           22
#             Books             16
#             Home & Kitchen    14
# Chennai     Home & Kitchen    25
#             Electronics       20
#             Fashion           17
#             Books             14
# Coimbatore  Fashion           20
#             Electronics       17
#             Home & Kitchen    17
#             Books              9
# Delhi       Home & Kitchen    21
#             Fashion           16
#             Electronics       15
#             Books             11
# Hubli       Electronics       30
#             Fashion           17
#             Books             16
#             Home & Kitchen    15
# Hyderabad   Electronics       26
#             Home & Kitchen    26
#             Fashion           20
# ...

# %%
df["Order_Date"].head()
# Out:
# 0    2025-01-21
# 1    2025-05-11
# 2    2025-11-10
# 3    2025-07-07
# 4    2025-05-11
# Name: Order_Date, dtype: str

# %%
df["Year"] = df["Order_Date"].dt.year

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])

# %%
df["Month"] = df["Order_Date"].dt.month

# %%
df["Month_Name"] = df["Order_Date"].dt.month_name()

# %%
df[["Order_Date","Month","Year","Month_Name"]].head()
# Out:
#   Order_Date  Month  Year Month_Name
# 0 2025-01-21      1  2025    January
# 1 2025-05-11      5  2025        May
# 2 2025-11-10     11  2025   November
# 3 2025-07-07      7  2025       July
# 4 2025-05-11      5  2025        May

# %%
df.groupby("Month_Name")["Sales"].sum()
# Out:
# Month_Name
# April        2158200
# August        970700
# December     1742400
# February     1154900
# January      2641750
# July         1245300
# June         1140550
# March        1559200
# May          1775800
# November     1171250
# October      1990400
# September    1726750
# Name: Sales, dtype: int64

# %%
df.groupby(["Year","Month"])["Sales"].sum()
# Out:
# Year  Month
# 2025  1        2641750
#       2        1154900
#       3        1559200
#       4        2158200
#       5        1775800
#       6        1140550
#       7        1245300
#       8         970700
#       9        1726750
#       10       1990400
#       11       1171250
#       12       1742400
# Name: Sales, dtype: int64

# %%
df.groupby("Month")["Sales"].sum().min()
# Out:
# np.int64(970700)

# %%
df.groupby("Month_Name")["Order_ID"].count()
# Out:
# Month_Name
# April        96
# August       90
# December     84
# February     65
# January      90
# July         94
# June         79
# March        69
# May          78
# November     87
# October      87
# September    81
# Name: Order_ID, dtype: int64

# %%
df.groupby("Month_Name")["Order_ID"].count().idxmax()
# Out:
# 'April'

# %%
df.groupby("Month_Name")["Quantity"].sum()
# Out:
# Month_Name
# April        220
# August       226
# December     199
# February     154
# January      208
# July         218
# June         198
# March        150
# May          192
# November     217
# October      209
# September    175
# Name: Quantity, dtype: int64

# %%
df.groupby("Month")["Profit"].sum()
# Out:
# Month
# 1     792525.0
# 2     346470.0
# 3     467760.0
# 4     647460.0
# 5     532740.0
# 6     342165.0
# 7     373590.0
# 8     291210.0
# 9     518025.0
# 10    597120.0
# 11    351375.0
# 12    522720.0
# Name: Profit, dtype: float64

# %%
df["Cost"] = df["Sales"] * 0.70
df["Profit"] = df["Sales"] - df["Cost"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
monthly_sales = df.groupby(
    ["Month", "Month_Name"]
)["Sales"].sum().sort_index()

# %%
plt.figure(figsize=(10, 5))

plt.plot(
    monthly_sales.index.get_level_values("Month_Name"),
    monthly_sales.values,
    marker="o"
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
top_products = df.groupby("Product")["Sales"].sum().nlargest(10)

# %%
plt.figure(figsize=(10, 6))

top_products.plot(kind="bar")

plt.title("Top 10 Products by Sales")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

# %%
plt.figure(figsize=(8, 5))

category_sales.sort_values(ascending=False).plot(
    kind="bar"
)

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()

# %%
city_sales = df.groupby("City")["Sales"].sum()

# %%
plt.figure(figsize=(10, 6))

city_sales.sort_values(ascending=False).plot(
    kind="bar"
)

plt.title("Sales by City")
plt.xlabel("City")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)

plt.show()

# %%
rating_counts = df.groupby("Customer_ID")["Rating"].value_counts().sort_index()

# %%
plt.figure(figsize=(7, 5))

rating_counts.plot(kind="bar")

plt.title("Customer Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Orders")

plt.xticks(rotation=0)

plt.show()

# %%
df.groupby("City")["Quantity"].sum()
# Out:
# City
# Ahmedabad     183
# Bangalore     167
# Chennai       173
# Coimbatore    148
# Delhi         146
# Hubli         183
# Hyderabad     190
# Kochi         235
# Kolkata       158
# Mumbai        204
# Mysore        188
# Pune          186
# Warangal      205
# Name: Quantity, dtype: int64

# %%
city_avg_sales = df.groupby("City")["Sales"].mean()

# %%
city_avg_sales.sort_values(ascending=False).plot(kind="bar")

plt.title("Average Sales by City")
plt.xlabel("City")
plt.ylabel("Average Sales")
plt.xticks(rotation=45)
plt.show()

# %%
city_orders = df.groupby("City")["Order_ID"].count()

# %%
city_orders.sort_values(ascending=False).plot(kind="bar")

plt.title("Number of Orders by City")
plt.xlabel("City")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
city_sales.sort_values(ascending = False).head(10)
# Out:
# City
# Mysore       2330900
# Mumbai       2035800
# Warangal     2031150
# Kochi        1990650
# Bangalore    1672800
# Hubli        1637900
# Kolkata      1628500
# Hyderabad    1418150
# Pune         1196750
# Ahmedabad    1142000
# Name: Sales, dtype: int64

# %%
city_sales.sort_values(ascending=False).head(5).plot(kind="bar")

plt.title("Top 5 Cities by Sales")
plt.xlabel("City")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
city_sales.idxmax()
# Out:
# 'Mysore'

# %%
df.groupby("City")["Quantity"].idxmax()
# Out:
# City
# Ahmedabad     109
# Bangalore      70
# Chennai        94
# Coimbatore    155
# Delhi         210
# Hubli          35
# Hyderabad      92
# Kochi          37
# Kolkata        11
# Mumbai         13
# Mysore         56
# Pune          203
# Warangal       88
# Name: Quantity, dtype: int64

# %%
city_orders.idxmax()
# Out:
# 'Kochi'

# %%
df.groupby("Month")["Sales"].sum()
# Out:
# Month
# 1     2641750
# 2     1154900
# 3     1559200
# 4     2158200
# 5     1775800
# 6     1140550
# 7     1245300
# 8      970700
# 9     1726750
# 10    1990400
# 11    1171250
# 12    1742400
# Name: Sales, dtype: int64

# %%
monthly_sales = df.groupby(["Month","Month_Name"])["Sales"].sum().sort_index()
print(monthly_sales)
# Out:
# Month  Month_Name
# 1      January       2641750
# 2      February      1154900
# 3      March         1559200
# 4      April         2158200
# 5      May           1775800
# 6      June          1140550
# 7      July          1245300
# 8      August         970700
# 9      September     1726750
# 10     October       1990400
# 11     November      1171250
# 12     December      1742400
# Name: Sales, dtype: int64

# %%
df.groupby("Month")["Quantity"].sum()
# Out:
# Month
# 1     208
# 2     154
# 3     150
# 4     220
# 5     192
# 6     198
# 7     218
# 8     226
# 9     175
# 10    209
# 11    217
# 12    199
# Name: Quantity, dtype: int64

# %%
df.groupby("Month")["Order_ID"].count()
# Out:
# Month
# 1     90
# 2     65
# 3     69
# 4     96
# 5     78
# 6     79
# 7     94
# 8     90
# 9     81
# 10    87
# 11    87
# 12    84
# Name: Order_ID, dtype: int64

# %%
payment_counts = df["Payment_Method"].value_counts()

# %%
plt.figure(figsize=(8, 5))

payment_counts.plot(kind="bar")

plt.title("Orders by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Number of Orders")

plt.xticks(rotation=45)

plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(8, 8))

plt.pie(
    category_sales,
    labels=category_sales.index,
    autopct="%1.1f%%"
)

plt.title("Sales Distribution by Category")

plt.show()

# %%
numeric_data = df[[
    "Quantity","Price","Sales","Rating"
    ]]

# %%
correlation = numeric_data.corr()
print(correlation)
# Out:
#           Quantity     Price     Sales    Rating
# Quantity  1.000000  0.018093  0.277338  0.047782
# Price     0.018093  1.000000  0.841949 -0.011234
# Sales     0.277338  0.841949  1.000000  0.031506
# Rating    0.047782 -0.011234  0.031506  1.000000

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="karthik",
    database="ecommerce"
)

print("Connected successfully!")
# Out:
# Connected successfully!

# %%
df.head()
# Out:
#    Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0     10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1     10002  2025-05-11       C1150      Backpack         Fashion         1
# 2     10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3     10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4     10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
#
#    Price  Sales      City        State Payment_Method  Rating
# 0   1450   2900   Kolkata  West Bengal    Credit Card       5
# 1   3150   3150   Chennai   Tamil Nadu            UPI       3
# 2   5150  15450     Kochi       Kerala            UPI       3
# 3   1700   1700     Delhi        Delhi    Credit Card       1
# 4   2600   7800  Warangal    Telangana     Debit Card       5

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="karthik",
    database="ecommerce"
)

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 5.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.4 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:karthik@localhost/ecommerce"
)

# %%
with engine.connect() as connection:
    print("Connected successfully")
# Out:
# Connected successfully

# %%
df.to_sql(
    "ecommerce",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 1000

# %%
pd.read_sql(
    "SELECT * FROM ecommerce LIMIT 5",
    engine
)
# Out:
#    Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0     10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1     10002  2025-05-11       C1150      Backpack         Fashion         1
# 2     10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3     10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4     10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
#
#    Price  Sales      City        State Payment_Method  Rating
# 0   1450   2900   Kolkata  West Bengal    Credit Card       5
# 1   3150   3150   Chennai   Tamil Nadu            UPI       3
# 2   5150  15450     Kochi       Kerala            UPI       3
# 3   1700   1700     Delhi        Delhi    Credit Card       1
# 4   2600   7800  Warangal    Telangana     Debit Card       5

# %%
query = """
select Product,sum(Sales) as tot_sales
from ecommerce
group by Product
"""
pd.read_sql(query , engine)
# Out:
#              Product  tot_sales
# 0            T-Shirt    99250.0
# 1           Backpack   211600.0
# 2         Smartwatch  1146000.0
# 3          Desk Lamp   244500.0
# 4       Cookware Set   546950.0
# 5              Shoes   390950.0
# 6         Smartphone  4375750.0
# 7              Novel    82900.0
# 8              Jeans   155900.0
# 9       Coffee Maker   445550.0
# 10          Keyboard   350500.0
# 11            Laptop  6522850.0
# 12        Headphones   538700.0
# 13             Mouse   171650.0
# 14           Monitor  2387650.0
# 15  Programming Book   138950.0
# 16          Bedsheet   198400.0
# 17     Mixer Grinder   696150.0
# 18            Jacket   534200.0
# 19          Notebook    38800.0

# %%
query = """
select Product,sum(Sales) as tot_sales
from ecommerce
group by product
order by tot_sales desc;
"""
pd.read_sql(query,engine)
# Out:
#              Product  tot_sales
# 0             Laptop  6522850.0
# 1         Smartphone  4375750.0
# 2            Monitor  2387650.0
# 3         Smartwatch  1146000.0
# 4      Mixer Grinder   696150.0
# 5       Cookware Set   546950.0
# 6         Headphones   538700.0
# 7             Jacket   534200.0
# 8       Coffee Maker   445550.0
# 9              Shoes   390950.0
# 10          Keyboard   350500.0
# 11         Desk Lamp   244500.0
# 12          Backpack   211600.0
# 13          Bedsheet   198400.0
# 14             Mouse   171650.0
# 15             Jeans   155900.0
# 16  Programming Book   138950.0
# 17           T-Shirt    99250.0
# 18             Novel    82900.0
# 19          Notebook    38800.0

# %%
query ="""
select Product,sum(Sales) as tot_sales
from ecommerce
group by product
order by tot_sales desc
limit 10;
"""
top_10_products = pd.read_sql(query , engine)
top_10_products
# Out:
#          Product  tot_sales
# 0         Laptop  6522850.0
# 1     Smartphone  4375750.0
# 2        Monitor  2387650.0
# 3     Smartwatch  1146000.0
# 4  Mixer Grinder   696150.0
# 5   Cookware Set   546950.0
# 6     Headphones   538700.0
# 7         Jacket   534200.0
# 8   Coffee Maker   445550.0
# 9          Shoes   390950.0

# %%
query ="""
select Product,sum(Sales) as tot_sales
from ecommerce
group by product
order by tot_sales desc
limit 1;
"""
pd.read_sql(query , engine)
# Out:
#   Product  tot_sales
# 0  Laptop  6522850.0

# %%
import matplotlib.pyplot as plt

top_10_products.plot(
    x="Product",
    y="tot_sales",
    kind="bar",
    legend=False
)

plt.title("Top 10 Products by Revenue")
plt.xlabel("Product")
plt.ylabel("tot_sales")
plt.xticks(rotation=45)
plt.show()

# %%
query = """
select Category,sum(Sales) as tot_sales
from ecommerce
group by category;
"""
pd.read_sql(query , engine)
# Out:
#          Category   tot_sales
# 0         Fashion   1391900.0
# 1     Electronics  15493100.0
# 2  Home & Kitchen   2131550.0
# 3           Books    260650.0

# %%
query = """
select Category,sum(Sales) as tot_sales
from ecommerce
group by category
order by tot_sales desc;
"""
category_sales = pd.read_sql(query , engine)
category_sales
# Out:
#          Category   tot_sales
# 0     Electronics  15493100.0
# 1  Home & Kitchen   2131550.0
# 2         Fashion   1391900.0
# 3           Books    260650.0

# %%
query = """
select Category,sum(Sales) as tot_sales
from ecommerce
group by category
order by tot_sales desc
limit 1 ;
"""
pd.read_sql(query , engine)
# Out:
#       Category   tot_sales
# 0  Electronics  15493100.0

# %%
import matplotlib.pyplot as plt

category_sales.plot(
    x="Category",
    y="tot_sales",
    kind="bar",
    legend=False
)

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Tot_sales")
plt.xticks(rotation=45)
plt.show()

# %%
query = """
select City ,sum(Sales) as tot_sales
from ecommerce
group by City;
"""
pd.read_sql(query , engine)
# Out:
#           City  tot_sales
# 0      Kolkata  1628500.0
# 1      Chennai   824200.0
# 2        Kochi  1990650.0
# 3        Delhi   600850.0
# 4     Warangal  2031150.0
# 5         Pune  1196750.0
# 6    Ahmedabad  1142000.0
# 7       Mumbai  2035800.0
# 8        Hubli  1637900.0
# 9       Mysore  2330900.0
# 10   Hyderabad  1418150.0
# 11  Coimbatore   767550.0
# 12   Bangalore  1672800.0

# %%
query = """
select City ,sum(Sales) as tot_sales
from ecommerce
group by City
order by tot_sales desc;
"""
city_sales = pd.read_sql(query , engine)
city_sales
# Out:
#           City  tot_sales
# 0       Mysore  2330900.0
# 1       Mumbai  2035800.0
# 2     Warangal  2031150.0
# 3        Kochi  1990650.0
# 4    Bangalore  1672800.0
# 5        Hubli  1637900.0
# 6      Kolkata  1628500.0
# 7    Hyderabad  1418150.0
# 8         Pune  1196750.0
# 9    Ahmedabad  1142000.0
# 10     Chennai   824200.0
# 11  Coimbatore   767550.0
# 12       Delhi   600850.0

# %%
query = """
select City ,sum(Sales) as tot_sales
from ecommerce
group by City
limit 5;
"""
top_5_cities = pd.read_sql(query , engine)
top_5_cities
# Out:
#        City  tot_sales
# 0   Kolkata  1628500.0
# 1   Chennai   824200.0
# 2     Kochi  1990650.0
# 3     Delhi   600850.0
# 4  Warangal  2031150.0

# %%
import matplotlib.pyplot as plt

top_5_cities.plot(
    x="City",
    y="tot_sales",
    kind="bar",
    legend=False
)

plt.title("Top 5 Cities by Revenue")
plt.xlabel("City")
plt.ylabel("Tot_sales")
plt.xticks(rotation=45)
plt.show()

# %%
query = """
select City ,sum(Sales) as tot_sales
from ecommerce
group by City
limit 1;
"""
pd.read_sql(query , engine)
# Out:
#       City  tot_sales
# 0  Kolkata  1628500.0

# %%
df.to_csv("ecommerce_sales_cleaned.csv", index=False)

# %%
import os

os.path.exists("ecommerce_sales_cleaned.csv")
# Out:
# True

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head()
# Out:
#    Order_ID  Order_Date Customer_ID       Product        Category  Quantity  \
# 0     10001  2025-01-21       C1103       T-Shirt         Fashion         2
# 1     10002  2025-05-11       C1150      Backpack         Fashion         1
# 2     10003  2025-11-10       C1022    Smartwatch     Electronics         3
# 3     10004  2025-07-07       C1015     Desk Lamp  Home & Kitchen         1
# 4     10005  2025-05-11       C1051  Cookware Set  Home & Kitchen         3
#
#    Price  Sales      City        State Payment_Method  Rating
# 0   1450   2900   Kolkata  West Bengal    Credit Card       5
# 1   3150   3150   Chennai   Tamil Nadu            UPI       3
# 2   5150  15450     Kochi       Kerala            UPI       3
# 3   1700   1700     Delhi        Delhi    Credit Card       1
# 4   2600   7800  Warangal    Telangana     Debit Card       5

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\karth'

# %%
df.to_csv("ecommerce_sales_cleaned.csv", index=False)

# %%
import os

print(os.path.exists("ecommerce_sales_cleaned.csv"))
# Out:
# True

# %%
print(os.path.abspath("ecommerce_sales_cleaned.csv"))
# Out:
# C:\Users\karth\ecommerce_sales_cleaned.csv

# %%
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.arduinoIDE',
#  '.bash_history',
#  '.cagent',
#  '.codegpt',
#  '.config',
#  '.copilot',
#  '.crossnote',
#  '.dbclient',
#  '.docker',
#  '.eclipse',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.p2',
#  '.python_history',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  'a.py',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'demo',
#  'Documents',
#  'Downloads',
#  'ecommerce.db',
#  'ecommerce_sales_cleaned.csv',
#  'Favorites',
#  'financial_transactions.csv',
#  'Links',
#  'Local Settings',
#  'miktex-console.lock',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{52db3b1a-fc29-11ef-967f-81fbe312891b}.TM.blf',
#  'NTUSER.DAT{52db3b1a-fc29-11ef-967f-81fbe312891b}.TMContainer00000000000000000001.regtrans-ms',
# ...
